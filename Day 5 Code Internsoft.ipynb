# %%
#Modules and Packages
#import the library
import math

# %%
#Use it (ceiling rounding)
math.ceil(2.4)
# Out:
# 3

# %%
math.floor(2.4)
# Out:
# 2

# %%
#Exploring built-in modules
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
help(math.ceil)
# Out:
# Help on built-in function ceil in module math:
#
# ceil(x, /)
#     Return the ceiling of x as an Integral.
#
#     This is the smallest integer >= x.

# %%
#writing modules
#Writing packages
#Just an example, this won't work
import foo.bar
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 4
#       1 #writing modules
#       2 #Writing packages
#       3 #Just an example, this won't work
# ----> 4 import foo.bar
#
# ModuleNotFoundError: No module named 'foo'

# %%
# OR could do it this way
from foo import bar
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 # OR could do it this way
# ----> 2 from foo import bar
#
# ModuleNotFoundError: No module named 'foo'

# %%
__init__.py:
__all__=["bar"]
# Out:
#   Cell In[10], line 1
#     __init__.py:
#                 ^
# SyntaxError: invalid syntax

# %%
#Errors and Exception Handling
print('Hello')
# Out:
# Hello

# %%
#Try and except
try:
    f=open('testfile','w')
    f.write('Test write this')
except IOError:
    #This will only check for an IOError exception and then execute this print statement
    print("ERROR: Could not find file or read data")
else:
    print("Concent written successfully")
    f.close()
# Out:
# Concent written successfully

# %%
#Now,let's see what happens when we don't have write permission?(opening only with'r'):
try:
    f=open('testfile','r')
    f.write('Test write this')
except IOError:
    #This will only check for an IOError exception and then execute this print statement
    print("ERROR: Could not find file or read data")
else:
    print("Concent written successfully")
    f.close()
# Out:
# ERROR: Could not find file or read data

# %%
#We could have also just said except:if we were'nt sure what exception would occur.
try:
    f=open('testfile','w')
    f.write('Test write this')
except:
    #This will only check for an IOError exception and then execute this print statement
    print("ERROR: Could not find file or read data")
else:
    print("Concent written successfully")
    f.close()
# Out:
# Concent written successfully

# %%
try:
    f=open('testfile','w')
    f.write("Test write statement")
finally:
    print("Always execute finally code blocks")
# Out:
# Always execute finally code blocks

# %%
#We can use this in conjunction with except.Let's see a new example that will take into account a user putting in the wrong input:
def askint():
    try:
        val=int(input("Please enter an integer:"))
    except:
        print("Looks like you did not enter an integer!")
    finally:
        print("Finally,I executed!")
    print(val)

# %%
askint()
# Out:
# Please enter an integer: 56
# Finally,I executed!
# 56

# %%
askint()
# Out:
# Please enter an integer:
# Looks like you did not enter an integer!
# Finally,I executed!
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 askint()
#
# Cell In[16], line 9, in askint()
#       7 finally:
#       8     print("Finally,I executed!")
# ----> 9 print(val)
#
# UnboundLocalError: cannot access local variable 'val' where it is not associated with a value

# %%
def askint():
    try:
        val=int(input("Please enter an integer:"))
    except:
        print("Looks like you did not enter an integer!")
        val=int(input("Try again-Please enter an integer:"))
    finally:
        print("Finally,I executed!")
    print(val)

# %%
askint()
# Out:
# Please enter an integer: 45
# Finally,I executed!
# 45

# %%
askint()
# Out:
# Please enter an integer:
# Looks like you did not enter an integer!
# Try again-Please enter an integer:
# Finally,I executed!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3, in askint()
#       2 try:
# ----> 3     val=int(input("Please enter an integer:"))
#       4 except:
#
# ValueError: invalid literal for int() with base 10: ''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 askint()
#
# Cell In[20], line 6, in askint()
#       4 except:
#       5     print("Looks like you did not enter an integer!")
# ----> 6     val=int(input("Try again-Please enter an integer:"))
#       7 finally:
#       8     print("Finally,I executed!")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def askint():
    while True:
        try:
            val=int(input("Please enter an integer:"))
        except:
            print("Looks like you did not enter an integer!")
            continue
        else:
            print("Yep that's an integer")
            break
        finally:
            print("Finally,I executed!")
        print(val)

# %%
askint()
# Out:
# Please enter an integer: 6
# Yep that's an integer
# Finally,I executed!

# %%
#Database connectivity and operations using Python.
#For Example, the following is the example of connecting with MySQL database "my_database1" and creating table gradest and inserting values inside
#!/usr/bin/python
import sqlite3
#connecting with the database.
db = sqlite3.connect("my_database1.db")
# Drop table if it already exist using execute() method
db.execute("drop table if exists grades1")
# Create table as per requirement
db.execute("create table grades1(id int, name text, score int)")
#inserting values inside the created table
db.execute("insert into grades1(id, name, score) values (101, 'John', 99)")
db.execute("insert into grades1(id, name, score) values (102, 'Gary', 90)")
db.execute("insert into grades1(id, name, score) values (103, 'James', 80)")
db.execute("insert into grades1(id, name, score) values (104, 'Cathy', 85)")
db.execute("insert into grades1(id, name, score) values (105, 'Kris', 95)")

# %%
db.commit()

# %%
results=db.execute("select*from grades1 order by id")
for row in results:
    print(row)
print("-" * 60)
# Out:
# (101, 'John', 99)
# (102, 'Gary', 90)
# (103, 'James', 80)
# (104, 'Cathy', 85)
# (105, 'Kris', 95)
# ------------------------------------------------------------

# %%
results=db.execute("select * from grades1 where name = 'Gary' ") 
for row in results:
    print(row)
print("-" * 60)
# Out:
# (102, 'Gary', 90)
# ------------------------------------------------------------

# %%
results=db.execute("select * from grades1 where score >+ 90")
for row in results:
    print(row)
print("-" * 60)
# Out:
# (101, 'John', 99)
# (105, 'Kris', 95)
# ------------------------------------------------------------

# %%
results=db.execute("select name, score from grades1 order by score desc ")
for row in results:
    print(row)
print("-" * 60)
# Out:
# ('John', 99)
# ('Kris', 95)
# ('Gary', 90)
# ('Cathy', 85)
# ('James', 80)
# ------------------------------------------------------------

# %%
results=db.execute("select name, score from grades1 order by score ")
for row in results:
    print(row) 
print("-" * 60)
# Out:
# ('James', 80)
# ('Cathy', 85)
# ('Gary', 90)
# ('Kris', 95)
# ('John', 99)
# ------------------------------------------------------------

# %%
results=db.execute("select name, score from grades1 order by score ")
for row in results:
    print(row)
# Out:
# ('James', 80)
# ('Cathy', 85)
# ('Gary', 90)
# ('Kris', 95)
# ('John', 99)

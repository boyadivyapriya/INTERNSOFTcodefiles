# %%
#Strings and List objects
#Strings
#Creating a string
#single word
'hello'
# Out:
# 'hello'

# %%
#entire phrase
'This is also a string'
# Out:
# 'This is also a string'

# %%
str='hello'
str
# Out:
# 'hello'

# %%
#We can also use double quotes
"Stringbuilt with double quotes"
# Out:
# 'Stringbuilt with double quotes'

# %%
#Be careful with quotes!
'I'm using single quotes,but will create an error'
# Out:
#   Cell In[5], line 2
#     'I'm using single quotes,but will create an error'
#                                                      ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
"Now I'm ready to use the single quotes inside a string!"
# Out:
# "Now I'm ready to use the single quotes inside a string!"

# %%
#Printing a String
#We can simply declare a string
'Hello World'
# Out:
# 'Hello World'

# %%
#Note that we can't output multiple strings this way 
'Hello World 1'
'Hello world 2'
# Out:
# 'Hello world 2'

# %%
#we have to use print to output multiple strings 
print('Hello World 1')
'Hello world 2'
# Out:
# Hello World 1
# 'Hello world 2'

# %%
print 'Hello World 1'
print 'Hello World 2'
print 'use \n to print a new line'
print '\n'
print 'So what I mean?'
# Out:
#   Cell In[10], line 1
#     print 'Hello World 1'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print('Hello World 1')
print('Hello World 2')
print('use \n to print a new line')
print('\n')
print('So what I mean?')
# Out:
# Hello World 1
# Hello World 2
# use
#  to print a new line
#
#
# So what I mean?

# %%
#print 3 Alert!
# To use print function from python 3 in python 2
from __future__ import print_function
print ('Hello World')
# Out:
# Hello World

# %%
#String Basics
len('Hello World')
# Out:
# 11

# %%
#String Indexing
#Assign s as a string
s = 'Hello World'

# %%
#check
s
# Out:
# 'Hello World'

# %%
#print the object
print(s)
# Out:
# Hello World

# %%
#show first element (in this case a letter)
s[0]
# Out:
# 'H'

# %%
s[1]
# Out:
# 'e'

# %%
s[2]
# Out:
# 'l'

# %%
#Grab everything past the first term all the way to the length of s which is len(s)
s[1:]
# Out:
# 'ello World'

# %%
#Note that there is no change to the original s
s
# Out:
# 'Hello World'

# %%
#Grab everything up to 3rd index
s[:3]
# Out:
# 'Hel'

# %%
#Everything
s[:]
# Out:
# 'Hello World'

# %%
#Last letter (one index behind 0 so it loops back around)
s[-1]
# Out:
# 'd'

# %%
#Grab everything but last letter
s[:-1]
# Out:
# 'Hello Worl'

# %%
#Grab everything,but go in step size of 1
s[::1]
# Out:
# 'Hello World'

# %%
#Grab everything,but go in step size of 2
s[::2]
# Out:
# 'HloWrd'

# %%
#we can use this to print a string backwards
s[::-1]
# Out:
# 'dlroW olleH'

# %%
#String Properties
s
# Out:
# 'Hello World'

# %%
#Lets try to change the first letter to 'x'
s[0]='x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 #Lets try to change the first letter to 'x'
# ----> 2 s[0]='x'
#
# TypeError: 'str' object does not support item assignment

# %%
s
# Out:
# 'Hello World'

# %%
#Concatenate strings!
s + ' concatenate me!'
# Out:
# 'Hello World concatenate me!'

# %%
#we can reassign s completely though!
s = s + ' concatenate me!'

# %%
print(s)
# Out:
# Hello World concatenate me!

# %%
s
# Out:
# 'Hello World concatenate me!'

# %%
letter='z'

# %%
letter*56
# Out:
# 'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz'

# %%
#Basic Built-in String methods
s
# Out:
# 'Hello World concatenate me!'

# %%
#Upper Case a string
s.upper()
# Out:
# 'HELLO WORLD CONCATENATE ME!'

# %%
#Lower case a string
s.lower()
# Out:
# 'hello world concatenate me!'

# %%
#Split a string by blank space (this is the default)
s.split()
# Out:
# ['Hello', 'World', 'concatenate', 'me!']

# %%
#Split a string by a specific element(doesn't include the element that was split on)
s.split('o')
# Out:
# ['Hell', ' W', 'rld c', 'ncatenate me!']

# %%
#Print Formatting
'Insert anathor string with curly brackets:{}'.format({'The inserted string'})
# Out:
# "Insert anathor string with curly brackets:{'The inserted string'}"

# %%
#Location and Counting
print(s)
s.count('o')
# Out:
# Hello World concatenate me!
# 3

# %%
s.find('o')
# Out:
# 4

# %%
s.center(40,'z')
# Out:
# 'zzzzzzHello World concatenate me!zzzzzzz'

# %%
'hello\thi'.expandtabs()
# Out:
# 'hello   hi'

# %%
#Is check methods
s='hello'

# %%
#isalnum() will return "True" if all characters in S are alphanumeric.
s.isalnum()
# Out:
# True

# %%
#isalpha() will return "True" if all characters in S are alphabetic.
s.isalpha()
# Out:
# True

# %%
#islower() will return "True" if all cased characters in S are lowercase and there is atleast one cased character in S,False otherwise.
s.lower()
# Out:
# 'hello'

# %%
#isspace() will return "True" if all characters in S are whitespace.
s.isspace()
# Out:
# False

# %%
#istitle() will return "True" if S is a title cased string and there is at least one character in S, i.e. uppercase characters may only follow uncased characters and lowercase characters only cased ones. Return False otherwise.
s.istitle()
# Out:
# False

# %%
#isupper() will return "True" if all cased characters in S are uppercase and there is atleast one cased character in S,False otherwise.
s.upper()
# Out:
# 'HELLO'

# %%
#Another method is endswith() which is essentially same as boolean check on s[-1]
s.endswith('o')
# Out:
# True

# %%
#Built-in Reg.Expressions
s.split('e')
# Out:
# ['h', 'llo']

# %%
s.partition('e')
# Out:
# ('h', 'e', 'llo')

# %%
s
# Out:
# 'hello'

# %%
#Lists
#Assign a list to an variable named my_list
my_list = [1,2,3]

# %%
my_list = ['A string',23,45.65,'k']

# %%
len(my_list)
# Out:
# 4

# %%
#Indexing and Slicing
my_list = ['one','two','six',5,4]

# %%
#Grab element at index 0
my_list[0]
# Out:
# 'one'

# %%
#Grab index 1 and everything past it
my_list[1:]
# Out:
# ['two', 'six', 5, 4]

# %%
#Grab everything up to index 3
my_list[:3]
# Out:
# ['one', 'two', 'six']

# %%
#We can also use "+" to concatenate lists,just like we did for Strings.
my_list + ['new item']
# Out:
# ['one', 'two', 'six', 5, 4, 'new item']

# %%
#Note:This doesn't actually change the original list!
my_list
# Out:
# ['one', 'two', 'six', 5, 4]

# %%
#we can reassign the list to make the permanant change.
my_list = my_list + ['add new item permanently']

# %%
my_list
# Out:
# ['one', 'two', 'six', 5, 4, 'add new item permanently']

# %%
#We can also use the *for a duplicate method similar to strings
my_list*2
# Out:
# ['one',
#  'two',
#  'six',
#  5,
#  4,
#  'add new item permanently',
#  'one',
#  'two',
#  'six',
#  5,
#  4,
#  'add new item permanently']

# %%
#Assign doubling not permanent
my_list
# Out:
# ['one', 'two', 'six', 5, 4, 'add new item permanently']

# %%
#Basic List Methods
#Create a new list
l=[1,2,3]

# %%
#Use append method to permanently add an item to the end of a list
#Append
l.append('append me!')

# %%
#Show
l
# Out:
# [2, 3, 'append me!']

# %%
#Use pop to "pop off an item from the list. By default pop takes off the last index, but you can also specify which index to pop off.
#pop off the 0 indexed item
l.pop(0)
# Out:
# 1

# %%
#Show
l
# Out:
# [2, 3, 'append me!']

# %%
#Assign the popped element,remember default popped index is -1
popped_item = l.pop()

# %%
popped_item
# Out:
# 'append me!'

# %%
#Sow remaining list
l
# Out:
# [2, 3]

# %%
#Note that lists indexing will return an error if there is no element at the index
l[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[86], line 2
#       1 #Note that lists indexing will return an error if there is no element at the index
# ----> 2 l[100]
#
# IndexError: list index out of range

# %%
#We can use the sort method and the reverse methods to also effect your lists
new_list =['a','e','x','b','c']

# %%
#Show 
new_list
# Out:
# ['a', 'e', 'x', 'b', 'c']

# %%
#Use reverse to reverse order (this is permanent!)
new_list.reverse()

# %%
new_list
# Out:
# ['c', 'b', 'x', 'e', 'a']

# %%
#Use sort to sort the list (in this case alphabetical order,but for numbers it will go ascending)
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
#Nesting Lists
#Let's make three lists
lst_1=[1,2,3]
lst_2=[4,5,6]
lst_3=[7,8,9]
#Make a list of lists to form a matrix
matrix = [lst_1,lst_2,lst_3]

# %%
#Show
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
#Grab first item in matrix object
matrix[0]
# Out:
# [1, 2, 3]

# %%
#Grab first item of the first item in the matrix object
matrix[0][0]
# Out:
# 1

# %%
#List Comprehensions
#Build a list comprehension by deconstructing a for loop within a []
first_col = [row[0] for row in matrix]

# %%
first_col
# Out:
# [1, 4, 7]

# %%
#Advanced Lists
l=[1,2,3]

# %%
#Append
l.append(4)
l
# Out:
# [1, 2, 3, 4]

# %%
#Count
l.count(10)
# Out:
# 0

# %%
l.count(2)
# Out:
# 1

# %%
#Extend
#append:Appends object at end
x=[1,2,3]
x.append([4,5])
print(x)
# Out:
# [1, 2, 3, [4, 5]]

# %%
#Extend:Extends list by appending elements from the iterable
x=[1,2,3]
x.extend([4,5])
print(x)
#Note how extend append each element in that iterable.That is the key difference
# Out:
# [1, 2, 3, 4, 5]

# %%
#Index
#Index returns the element placed as an argument.Make a note that if element is not in the list then it returns an error.
print(l)
l.index(2)
# Out:
# [1, 2, 3, 4]
# 1

# %%
l.index(12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 l.index(12)
#
# ValueError: 12 is not in list

# %%
#Insert
#Two arguments can be placed in insert method.
#Syntax: insert(index, object)
#This method places the object at the index supplied.
l
# Out:
# [1, 2, 3, 4]

# %%
#Place a letter at the index 2
l.insert(2,'inserted')

# %%
l
# Out:
# [1, 2, 'inserted', 3, 4]

# %%
#pop
#It allows you to "pop" off the last element of a list.
ele = l.pop()

# %%
l
# Out:
# [1, 2, 'inserted', 3]

# %%
ele
# Out:
# 4

# %%
#Remove:This method removes the first occurance of a value
l
# Out:
# [1, 2, 'inserted', 3]

# %%
l.remove('inserted')

# %%
l
# Out:
# [1, 2, 3]

# %%
l = [1,4,3,6,5,2]

# %%
l.remove(3)

# %%
l
# Out:
# [1, 4, 6, 5, 2]

# %%
#Reverse:It helps you to reverse a list.Note this occurs in place!Meaning it effects your list permanently.
l.reverse()

# %%
l
# Out:
# [2, 5, 6, 4, 1]

# %%
#Sort:It will sort your list in place
l
# Out:
# [2, 5, 6, 4, 1]

# %%
l.sort()

# %%
l
# Out:
# [1, 2, 4, 5, 6]

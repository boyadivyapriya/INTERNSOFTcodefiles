# %%
#Object Oriented Programming and File I/O
#How to define classes
#Creating a class
class Person:
    pass
john_doe=Person() 
john_doe.name="Alec"
john_doe.Surname="Baldwin"
john_doe.year_of_birth=1958

print(john_doe)
print("%s %s was born in %d." %
      (john_doe.name,john_doe.Surname,john_doe.year_of_birth))
# Out:
# <__main__.Person object at 0x000001901BFBD2B0>
# Alec Baldwin was born in 1958.

# %%
class Person:
    def __init__(self,name,surname,year_of_birth):
        self.name=name
        self.surname=surname
        self.year_of_birth=year_of_birth

# %%
alec=Person("Alec","Balwin",1958)
print(alec)
print("%s %s was born in %d"%(alec.name,alec.surname,alec.year_of_birth))
# Out:
# <__main__.Person object at 0x000001901BFBD940>
# Alec Balwin was born in 1958

# %%
#Methods
class Person:
    def __init__(self,name,surname,year_of_birth):
        self.name=name
        self.surname=surname
        self.year_of_birth=year_of_birth
    def age(self,current_year):
        return current_year - self.year_of_birth
    def __str__(self):
        return "%s %s was born in %d ." % (self.name, self.surname, self.year_of_birth)
alec=Person("Alec", "Baldwin", 1958)
print(alec)
print(alec.age(2019))
# Out:
# Alec Baldwin was born in 1958 .
# 61

# %%
#Methods
class Person:
    def __init__(self,name,surname,year_of_birth):
        self.name=name
        self.surname=surname
        self.year_of_birth=year_of_birth
    def age(self,current_year):
        return current_year - self.year_of_birth
    def __str__(self):
        return "%s %s was born in %d ." % (self.name, self.surname, self.year_of_birth)
alec=Person("Divya", "Priya", 2003)
print(alec)
print(alec.age(2025))
# Out:
# Divya Priya was born in 2003 .
# 22

# %%
#Inheritance
class Student(Person):
    def __init__(self,student_id, *args, ** kwargs):
        super(Student,self).__init__(*args, **kwargs)
        self._student_id=student_id
Charlie = Student(1, 'Charlie', 'Brown', 2006)
print(charlie)
print(type(charlie))
print(isinstance(charlie,Person))
print(isinstance(charlie,object))
# Out:
# Charlie Brown was born in 2006 .
# <class '__main__.Student'>
# True
# True

# %%
#Overriding method
class Student(Person):
     def __init__(self,student_id, *args, ** kwargs):
        super(Student,self).__init__(*args, **kwargs)
        self._student_id=student_id
     def __str__(self): 
         return super(Student,self).__str__() + "And has ID: %d" % self._student_id
charlie = Student(1, 'Charlie', 'Brown', 2006)
print(charlie)
# Out:
# Charlie Brown was born in 2006 .And has ID: 1

# %%
#Encapsulation
#Composition
#Polymorphism and DuckTypig
def summer(a,b):
    return a+b
print(summer(1,1))
print(summer(["a", "b", "c"], ["d", "e"]))
print(summer("abra", "cadabra"))
# Out:
# 2
# ['a', 'b', 'c', 'd', 'e']
# abracadabra

# %%
#How long does a class should be?
#Files
#iPython Writing a File

# %%
# %%writefile superman.txt
# Hello, this is a quick superman test file
# Out:
# Writing superman.txt

# %%
#Python Opening a file
#Open the text.txt we made earlier
my_file = open('superman.txt')

# %%
#We can now read the file
my_file.read()
# Out:
# 'Hello, this is a quick superman test file\n'

# %%
#But what happens if we try to read again?
my_file.read()
# Out:
# ''

# %%
#Seek to the start of file (index 0)
my_file.seek(0)
# Out:
# 0

# %%
#Now read again
my_file.read()
# Out:
# 'Hello, this is a quick superman test file\n'

# %%
#Seek to the start of file (index 0)
my_file.seek(0)
# Out:
# 0

# %%
#Readlines returns a list of the lines in the file.
my_file.readlines()
# Out:
# []

# %%
#Writing to a File
#Add the second argument to the function, 'w' which stands for write
my_file=open('superman.txt','w+')

# %%
#write to the file
my_file.write('This is a new line')
# Out:
# 18

# %%
#Seek to start of file(index0)
my_file.seek(0)
# Out:
# 0

# %%
#Read the file
my_file.read()
# Out:
# 'This is a new line'

# %%
#Iterating through a File

# %%
# %%writefile test.txt
# First Line
# Second Line
# Out:
# Writing test.txt

# %%
for line in open('test.txt'):
    print(line)
# Out:
# First Line
#
# Second Line

# %%
#Pertaining to the first pont above
for asdf in open('test.txt'):
    print(asdf)
# Out:
# First Line
#
# Second Line

# %%
#StringIO
from io import StringIO

# %%
#Arbitary String
message = 'This is just a normal string.'

# %%
#Use StringIO method to set as file object
f= StringIO(message)

# %%
f.read()
# Out:
# 'This is just a normal string.'

# %%
f.write('Second line written to file like object')
# Out:
# 39

# %%
#Reset cursor just like you would a file
f.seek(0)
# Out:
# 0

# %%
#Read again 
f.read()
# Out:
# 'This is just a normal string.Second line written to file like object'
